# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import plotly.express as px
import cufflinks as cf
import numpy as np
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_excel('CAP-samenvoeging.xlsx')
df
# Out:
#                                        Method name N (no. labs)  Mean  Bias  \
# 0      (Ortho Clin Diag) Vitros 5.1 FS Chem System          183  6.14 -0.16
# 1      (Ortho Clin Diag) Vitros 5.1 FS Chem System          183  7.59 -0.01
# 2      (Ortho Clin Diag) Vitros 5.1 FS Chem System          183  9.42  0.22
# 3      (Ortho Clin Diag) Vitros 5.1 FS Chem System          210  5.42 -0.18
# 4      (Ortho Clin Diag) Vitros 5.1 FS Chem System          210  9.34 -0.06
# ...                                            ...          ...   ...   ...
# 4165  Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems          204  9.08  0.22
# 4166  Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems          204  6.86  0.02
# 4167  Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems          204  9.40  0.01
# 4168  Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems          204  6.14  0.01
# 4169  Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems          204  7.59  0.07
#
#        CV  Sample  Reference Value  Year Source (CAP/EurA1c)  \
# 0     2.3  GH2-04             6.30  2011                 CAP
# 1     2.5  GH2-05             7.60  2011                 CAP
# 2     3.0  GH2-06             9.20  2011                 CAP
# 3     2.3  GH2-01             5.60  2012                 CAP
# 4     2.6  GH2-02             9.40  2012                 CAP
# ...   ...     ...              ...   ...                 ...
# 4165  3.1  GH5-01             8.86  2021                 CAP
# 4166  2.6  GH5-02             6.84  2021                 CAP
# 4167  3.4  GH5-03             9.39  2021                 CAP
# 4168  2.5  GH5-04             6.13  2021                 CAP
# 4169  2.8  GH5-05             7.52  2021                 CAP
#
#      Type (Fresh/frozen) Manufacturer  Total Error
# 0                  Fresh       Vitros         2.48
# 1                  Fresh       Vitros         2.49
# 2                  Fresh       Vitros         3.22
# 3                  Fresh       Vitros         2.12
# 4                  Fresh       Vitros         2.54
# ...                  ...          ...          ...
# 4165               Fresh       Vitros         3.32
# 4166               Fresh       Vitros         2.62
# 4167               Fresh       Vitros         3.41
# 4168               Fresh       Vitros         2.51
# 4169               Fresh       Vitros         2.87
#
# [4170 rows x 12 columns]

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3544 entries, 0 to 4169
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Method name          3544 non-null   object
#  1   N (no. labs)         3544 non-null   object
#  2   Mean                 3544 non-null   float64
#  3   Bias                 3544 non-null   float64
#  4   CV                   3544 non-null   float64
#  5   Sample               3544 non-null   object
#  6   Reference Value      3544 non-null   float64
#  7   Year                 3544 non-null   int64
#  8   Source (CAP/EurA1c)  3544 non-null   object
#  9   Type (Fresh/frozen)  3544 non-null   object
#  10  Manufacturer         3544 non-null   object
#  11  Total Error          3544 non-null   float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 359.9+ KB

# %%
df2 = df.groupby(['Method name','Year']).mean().reset_index()
df3 = df2.set_index('Method name')
df3
# Out:
#                                                 Year      Mean      Bias  \
# Method name
# (Ortho Clin Diag) Vitros 5.1 FS Chem System     2011  7.716667  0.016667
# (Ortho Clin Diag) Vitros 5.1 FS Chem System     2012  7.256667 -0.143333
# (Ortho Clin Diag) Vitros 5.1 FS. 4600. 5600     2014  7.166667 -0.121667
# (Ortho Clin Diag) Vitros 5.1 FS. 4600. 5600     2015  7.619333 -0.218667
# (Ortho Clin Diag) Vitros 5.1 FS. 4600. 5600     2016  8.028000  0.095333
# ...                                              ...       ...       ...
# Vitros 5.1 FS/4600/5600 Chemistry Systems       2019  7.035333  0.002000
# Vitros 5.1 FS/4600/5600 Chemistry Systems       2020  7.266000 -0.073000
# Vitros 5.1 FS/4600/5600/XT\n7600 Chem. Systems  2020  6.800000 -0.186000
# Vitros 5.1 FS/4600/5600/XT\n7600 Chem. Systems  2021  7.185556 -0.024444
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems    2021  7.814000  0.066000
#
#                                                       CV  Reference Value  \
# Method name
# (Ortho Clin Diag) Vitros 5.1 FS Chem System     2.600000         7.700000
# (Ortho Clin Diag) Vitros 5.1 FS Chem System     2.433333         7.400000
# (Ortho Clin Diag) Vitros 5.1 FS. 4600. 5600     2.500000         7.288333
# (Ortho Clin Diag) Vitros 5.1 FS. 4600. 5600     3.040000         7.838000
# (Ortho Clin Diag) Vitros 5.1 FS. 4600. 5600     2.700000         7.932667
# ...                                                  ...              ...
# Vitros 5.1 FS/4600/5600 Chemistry Systems       2.820000         7.033333
# Vitros 5.1 FS/4600/5600 Chemistry Systems       2.750000         7.339000
# Vitros 5.1 FS/4600/5600/XT\n7600 Chem. Systems  2.580000         6.986000
# Vitros 5.1 FS/4600/5600/XT\n7600 Chem. Systems  2.522222         7.210000
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems    2.880000         7.748000
#
#                                                 Total Error
# Method name
# (Ortho Clin Diag) Vitros 5.1 FS Chem System        2.730000
# (Ortho Clin Diag) Vitros 5.1 FS Chem System        2.290000
# (Ortho Clin Diag) Vitros 5.1 FS. 4600. 5600        2.378333
# (Ortho Clin Diag) Vitros 5.1 FS. 4600. 5600        2.821333
# (Ortho Clin Diag) Vitros 5.1 FS. 4600. 5600        2.795333
# ...                                                     ...
# Vitros 5.1 FS/4600/5600 Chemistry Systems          2.822000
# Vitros 5.1 FS/4600/5600 Chemistry Systems          2.677000
# Vitros 5.1 FS/4600/5600/XT\n7600 Chem. Systems     1.794000
# Vitros 5.1 FS/4600/5600/XT\n7600 Chem. Systems     2.503333
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems       2.946000
#
# [409 rows x 6 columns]

# %%
df4 = df.set_index('Method name')
df4
# Out:
#                                              N (no. labs)  Mean  Bias   CV  \
# Method name
# (Ortho Clin Diag) Vitros 5.1 FS Chem System           183  6.14 -0.16  2.3
# (Ortho Clin Diag) Vitros 5.1 FS Chem System           183  7.59 -0.01  2.5
# (Ortho Clin Diag) Vitros 5.1 FS Chem System           183  9.42  0.22  3.0
# (Ortho Clin Diag) Vitros 5.1 FS Chem System           210  5.42 -0.18  2.3
# (Ortho Clin Diag) Vitros 5.1 FS Chem System           210  9.34 -0.06  2.6
# ...                                                   ...   ...   ...  ...
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems          204  9.08  0.22  3.1
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems          204  6.86  0.02  2.6
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems          204  9.40  0.01  3.4
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems          204  6.14  0.01  2.5
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems          204  7.59  0.07  2.8
#
#                                               Sample  Reference Value  Year  \
# Method name
# (Ortho Clin Diag) Vitros 5.1 FS Chem System   GH2-04             6.30  2011
# (Ortho Clin Diag) Vitros 5.1 FS Chem System   GH2-05             7.60  2011
# (Ortho Clin Diag) Vitros 5.1 FS Chem System   GH2-06             9.20  2011
# (Ortho Clin Diag) Vitros 5.1 FS Chem System   GH2-01             5.60  2012
# (Ortho Clin Diag) Vitros 5.1 FS Chem System   GH2-02             9.40  2012
# ...                                              ...              ...   ...
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems  GH5-01             8.86  2021
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems  GH5-02             6.84  2021
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems  GH5-03             9.39  2021
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems  GH5-04             6.13  2021
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems  GH5-05             7.52  2021
#
#                                              Source (CAP/EurA1c)  \
# Method name
# (Ortho Clin Diag) Vitros 5.1 FS Chem System                  CAP
# (Ortho Clin Diag) Vitros 5.1 FS Chem System                  CAP
# (Ortho Clin Diag) Vitros 5.1 FS Chem System                  CAP
# (Ortho Clin Diag) Vitros 5.1 FS Chem System                  CAP
# (Ortho Clin Diag) Vitros 5.1 FS Chem System                  CAP
# ...                                                          ...
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems                 CAP
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems                 CAP
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems                 CAP
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems                 CAP
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems                 CAP
#
#                                              Type (Fresh/frozen) Manufacturer  \
# Method name
# (Ortho Clin Diag) Vitros 5.1 FS Chem System                Fresh       Vitros
# (Ortho Clin Diag) Vitros 5.1 FS Chem System                Fresh       Vitros
# (Ortho Clin Diag) Vitros 5.1 FS Chem System                Fresh       Vitros
# (Ortho Clin Diag) Vitros 5.1 FS Chem System                Fresh       Vitros
# (Ortho Clin Diag) Vitros 5.1 FS Chem System                Fresh       Vitros
# ...                                                          ...          ...
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems               Fresh       Vitros
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems               Fresh       Vitros
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems               Fresh       Vitros
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems               Fresh       Vitros
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems               Fresh       Vitros
#
#                                               Total Error
# Method name
# (Ortho Clin Diag) Vitros 5.1 FS Chem System          2.48
# (Ortho Clin Diag) Vitros 5.1 FS Chem System          2.49
# (Ortho Clin Diag) Vitros 5.1 FS Chem System          3.22
# (Ortho Clin Diag) Vitros 5.1 FS Chem System          2.12
# (Ortho Clin Diag) Vitros 5.1 FS Chem System          2.54
# ...                                                   ...
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems         3.32
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems         2.62
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems         3.41
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems         2.51
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems         2.87
#
# [3544 rows x 11 columns]

# %%
df5 = df3[['Year','Bias','CV','Total Error']]
df5
# Out:
#                                                 Year      Bias        CV  \
# Method name
# (Ortho Clin Diag) Vitros 5.1 FS Chem System     2011  0.016667  2.600000
# (Ortho Clin Diag) Vitros 5.1 FS Chem System     2012 -0.143333  2.433333
# (Ortho Clin Diag) Vitros 5.1 FS. 4600. 5600     2014 -0.121667  2.500000
# (Ortho Clin Diag) Vitros 5.1 FS. 4600. 5600     2015 -0.218667  3.040000
# (Ortho Clin Diag) Vitros 5.1 FS. 4600. 5600     2016  0.095333  2.700000
# ...                                              ...       ...       ...
# Vitros 5.1 FS/4600/5600 Chemistry Systems       2019  0.002000  2.820000
# Vitros 5.1 FS/4600/5600 Chemistry Systems       2020 -0.073000  2.750000
# Vitros 5.1 FS/4600/5600/XT\n7600 Chem. Systems  2020 -0.186000  2.580000
# Vitros 5.1 FS/4600/5600/XT\n7600 Chem. Systems  2021 -0.024444  2.522222
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems    2021  0.066000  2.880000
#
#                                                 Total Error
# Method name
# (Ortho Clin Diag) Vitros 5.1 FS Chem System        2.730000
# (Ortho Clin Diag) Vitros 5.1 FS Chem System        2.290000
# (Ortho Clin Diag) Vitros 5.1 FS. 4600. 5600        2.378333
# (Ortho Clin Diag) Vitros 5.1 FS. 4600. 5600        2.821333
# (Ortho Clin Diag) Vitros 5.1 FS. 4600. 5600        2.795333
# ...                                                     ...
# Vitros 5.1 FS/4600/5600 Chemistry Systems          2.822000
# Vitros 5.1 FS/4600/5600 Chemistry Systems          2.677000
# Vitros 5.1 FS/4600/5600/XT\n7600 Chem. Systems     1.794000
# Vitros 5.1 FS/4600/5600/XT\n7600 Chem. Systems     2.503333
# Vitros 5.1 FS/4600/5600/XT7600 Chem. Systems       2.946000
#
# [409 rows x 4 columns]

# %%
def plotCV(method):
    df3.loc[[method]].iplot(
                    xTitle='Year',
                    x = 'Year',
                    y = 'CV',
                    mode='lines+markers',
                    yTitle='CV {}'.format(method)
                    
        
                     )

# %%
interact(plotCV, method=df3.index.unique())
# Out:
# interactive(children=(Dropdown(description='method', options=('(Ortho Clin Diag) Vitros 5.1 FS Chem System', '…
# <function __main__.plotCV(method)>

# %%
def plotBias(method):
    df3.loc[[method]].iplot(
                    xTitle='Year',
                    x = 'Year',
                    y = 'Bias',
                    mode='lines+markers',
                    yTitle='Bias {}'.format(method)
                    
        
                     )

# %%
interact(plotBias, method=df3.index.unique())
# Out:
# interactive(children=(Dropdown(description='method', options=('(Ortho Clin Diag) Vitros 5.1 FS Chem System', '…
# <function __main__.plotBias(method)>

# %%
def plotTotalError(method):
    df3.loc[[method]].iplot(
                    xTitle='Year',
                    x = 'Year',
                    y = 'Total Error',
                    mode='lines+markers',
                    yTitle='Total Error {}'.format(method)
                    
        
                     )

# %%
interact(plotTotalError, method=df3.index.unique())
# Out:
# interactive(children=(Dropdown(description='method', options=('(Ortho Clin Diag) Vitros 5.1 FS Chem System', '…
# <function __main__.plotTotalError(method)>

# %%
def plotEverything(method):
    df5.loc[[method]].iplot(
                    xTitle='Year',
                    x = 'Year',
                    mode='lines+markers',
                    yTitle='Total Error {}'.format(method)
                    
        
                     )

# %%
interact(plotEverything, method=df3.index.unique())
# Out:
# interactive(children=(Dropdown(description='method', options=('(Ortho Clin Diag) Vitros 5.1 FS Chem System', '…
# <function __main__.plotEverything(method)>
