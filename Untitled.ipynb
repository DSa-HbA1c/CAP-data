# %%
import pandas as pd
jaar20 = pd.read_excel('CAP20.xlsx')
jaar09 = pd.read_excel('CAP2019.xlsx')
jaar18 = pd.read_excel('CAP2009.xlsx')
jaar08 = pd.read_excel('CAP2008.xlsx')
jaar16 = pd.read_excel('CAP2016.xlsx')
jaar15 = pd.read_excel('CAP2015.xlsx')
jaar14 = pd.read_excel('CAP2014.xlsx')
jaar13 = pd.read_excel('CAP2013.xlsx')
jaar12 = pd.read_excel('CAP2012.xlsx')
jaar07 = pd.read_excel('CAP2007.xlsx')
jaar10 = pd.read_excel('CAP2010.xlsx')

complete = pd.concat([jaar08,jaar09,jaar07,jaar20,jaar16,jaar15,jaar14,jaar13,jaar12,jaar10])
complete
# Out:
#                    Method name    N   Mean   CV  Sample  Reference Value  \
# 0     Abbott Architect/Aeroset   49  12.50  5.1  GH2-01             13.0
# 1     Abbott Architect/Aeroset   49   5.10  4.2  GH2-02              5.3
# 2     Abbott Architect/Aeroset   49   9.20  5.1  GH2-03              8.8
# 3     Abbott Architect/Aeroset   47  11.70  4.8  GH2-04             11.9
# 4     Abbott Architect/Aeroset   47   6.90  4.3  GH2-05              6.8
# ..                         ...  ...    ...  ...     ...              ...
# 172  Vitros 5,1 FS Chem System  132  10.20  3.7  GH2-02              9.8
# 173  Vitros 5,1 FS Chem System  132   7.85  3.7  GH2-03              7.4
# 174  Vitros 5,1 FS Chem System  154   5.52  4.6  GH2-04              5.2
# 175  Vitros 5,1 FS Chem System  154   8.92  3.4  GH2-05              8.7
# 176  Vitros 5,1 FS Chem System  154   6.57  3.7  GH2-06              6.3
#
#      Year Source   Type  Bias
# 0    2008    CAP  Fresh   NaN
# ...

# %%
complete = complete.sort_values(by=['Method name']).reset_index()
complete.tail(60)
# Out:
#       index                                     Method name    N   Mean   CV  \
# 2437    181            Trinity Biotech Premier Hb9210\nHPLC   80   5.51  2.1
# 2438    133            Trinity Biotech Premier Hb9210\nHPLC   80   9.31  2.3
# 2439    202            Trinity Biotech Premier Hb9210\nHPLC   80   7.50  1.8
# 2440    350            Trinity Biotech Premier Hb9210\nHPLC   79   5.20  2.0
# 2441    223            Trinity Biotech Premier Hb9210\nHPLC   80   9.93  1.9
# 2442    237            Trinity Biotech Premier Hb9210\nHPLC   71   5.97  2.5
# 2443    106            Trinity Biotech Premier Hb9210\nHPLC   80   7.53  2.5
# 2444    263            Trinity Biotech Premier Hb9210\nHPLC   71   9.81  2.1
# 2445    292            Trinity Biotech Premier Hb9210\nHPLC   79   5.47  1.8
# 2446    130                         Vitros 5,1 FS Chem Syst   83  11.20  5.3
# 2447    128                         Vitros 5,1 FS Chem Syst   66   7.70  4.0
# ...
